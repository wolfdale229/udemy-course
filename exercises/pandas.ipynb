# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/airlines.csv')

# %%
df
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %%
df.head(10)
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
# 5             Air France              3004002661               14
# 6             Air India*               869253552                2
# 7       Air New Zealand*               710174817                3
# 8       Alaska Airlines*               965346773                5
# 9               Alitalia               698012498                7
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# ...

# %%
df.shape
# Out:
# (56, 8)

# %%
len(df.columns)
# Out:
# 8

# %%
df.columns
# Out:
# Index(['airline', 'avail_seat_km_per_week', 'incidents_85_99',
#        'fatal_accidents_85_99', 'fatalities_85_99', 'incidents_00_14',
#        'fatal_accidents_00_14', 'fatalities_00_14'],
#       dtype='object')

# %%
len(df)
# Out:
# 56

# %%
df.index
# Out:
# RangeIndex(start=0, stop=56, step=1)

# %%
df
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %%
df['incidents_85_99'] = df['incidents_85_99'].astype(float)
df
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734              2.0
# 1                    Aeroflot*              1197672318             76.0
# 2        Aerolineas Argentinas               385803648              6.0
# 3                  Aeromexico*               596871813              3.0
# 4                   Air Canada              1865253802              2.0
# 5                   Air France              3004002661             14.0
# 6                   Air India*               869253552              2.0
# 7             Air New Zealand*               710174817              3.0
# 8             Alaska Airlines*               965346773              5.0
# 9                     Alitalia               698012498              7.0
# 10          All Nippon Airways              1841234177              3.0
# 11                   American*              5228357340             21.0
# ...
